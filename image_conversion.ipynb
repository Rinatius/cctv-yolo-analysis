# %%
import sys
import argparse
from yolo import YOLO, detect_video
from PIL import Image
from cv2 import imwrite
import numpy as np
import cv2
# Out:
# Using TensorFlow backend.

# %%
image = Image.open('images/neuro_men.jpg')
yolo = YOLO()
r_image = yolo.detect_image(image)
yolo.close_session()
# Out:
# model_data/yolo.h5 model, anchors, and classes loaded.
# (416, 416, 3)
# Found 40 boxes for img
# ------------OUT_BOXES------------
# [[ 605.76953  333.30856 1129.3425   476.7558 ]
#  [ 617.9682  2247.3306  1171.8027  2449.305  ]
#  [ 611.3343    10.69841 1188.5686   211.11125]
#  [ 654.88135  580.03314 1101.9017   713.6629 ]
#  [ 651.6512   461.01242 1105.8583   608.08997]
#  [ 671.1784   859.5704  1031.696    984.6162 ]
#  [ 608.71686  176.9306  1181.4883   369.10696]
#  [ 663.1785  1970.7098  1095.8207  2114.555  ]
#  [ 651.3388  1333.7101  1035.0735  1459.7312 ]
#  [ 667.3092  1232.1841  1031.8129  1349.7361 ]
#  [ 658.3482   689.2216  1075.3646   799.85516]
#  [ 662.20386  964.6753  1035.7002  1079.2438 ]
#  [ 652.8272  2103.9917  1112.9172  2257.468  ]
#  [ 636.2778  1721.7324  1070.7146  1859.3577 ]
#  [ 658.75494 1060.963   1034.5001  1176.8802 ]
#  [ 666.21906 1530.765   1057.8251  1658.0281 ]
#  [ 672.2687   760.86444 1042.5809   871.8259 ]
# ...

# %%
r_image['image'].show()

# %%
r_image['image'].save('images/persons_ties.jpg')

# %%
video_path = '/home/rinat/wl/wl_bw.mp4'
cap = cv2.VideoCapture(video_path) #video_name is the video being called
cap.set(1,25845); # Where frame_no is the frame you want
ret, frame = cap.read() # Read the frame
#cv2.imshow('window_name', frame)

# %%
yolo = YOLO()
r_image = yolo.detect_image(img)
yolo.close_session()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/keras-yolo3/yolo.py in generate(self)
#      72         try:
# ---> 73             self.yolo_model = load_model(model_path, compile=False)
#      74         except:
#
# ~/miniconda3/envs/keras-yolo3_gpu/lib/python3.6/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     262         # set weights
# --> 263         load_weights_from_hdf5_group(f['model_weights'], model.layers)
#     264
#
# ~/miniconda3/envs/keras-yolo3_gpu/lib/python3.6/site-packages/keras/engine/saving.py in load_weights_from_hdf5_group(f, layers, reshape)
#     927         weight_value_tuples += zip(symbolic_weights, weight_values)
# --> 928     K.batch_set_value(weight_value_tuples)
#     929
#
# ~/miniconda3/envs/keras-yolo3_gpu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in batch_set_value(tuples)
# ...

# %%
img = Image.fromarray(frame)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=950x720 at 0x7F9A5156B668>

# %%
r_image['image']
# Out:
# <PIL.Image.Image image mode=RGB size=950x720 at 0x7F99EC6925C0>
